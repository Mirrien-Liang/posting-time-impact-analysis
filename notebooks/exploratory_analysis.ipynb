# %% [markdown]
# # Preliminary Playaround
#
# ## Loading data
#
# ### Prepare columns of interest and specify their types

# %%
import pandas as pd

# Init constant var to store desired cols and their types
DTYPE_DICT = {
    "user_id": pd.Int64Dtype(),
    "status": pd.StringDtype(),
    "timestamp": pd.Int64Dtype(),
    "data.user_data.meta.is_private": pd.BooleanDtype(),
    "data.user_data.meta.is_verified": pd.BooleanDtype(),
    "data.user_data.meta.is_business_account": pd.BooleanDtype(),
    "data.user_data.meta.is_professional_account": pd.BooleanDtype(),
    "data.user_data.meta.has_reel": pd.BooleanDtype(),
    "data.user_data.meta.total_posts_count": pd.Int64Dtype(),
    "data.user_data.meta.followers_count": pd.Int64Dtype(),
    "data.user_data.meta.followings_count": pd.Int64Dtype(),
}

# Iteratively get the metrics for posts
post_column_pattern = "data.user_data.post.{}.{}"
post_metrics = {
    "is_video": pd.BooleanDtype(),
    "video_view_count": pd.Int64Dtype(),
    "comments_count": pd.Int64Dtype(),
    "comments_disabled": pd.BooleanDtype(),
    "taken_at_timestamp": pd.Int64Dtype(),
    "likes_count": pd.Int64Dtype(),
    "is_pinned": pd.BooleanDtype(),
}

# Populate DTYPE_DICT with desired metrics for 12 posts
for i in range(1, 13):
    for metric, dtype in post_metrics.items():
        column_name = post_column_pattern.format(i, metric)
        DTYPE_DICT[column_name] = dtype

# Iteratively get the metrics for reels
reel_column_pattern = "data.user_data.reel.{}.{}"
reel_metrics = {
    "has_audio": pd.BooleanDtype(),
    "video_view_count": pd.Int64Dtype(),
    "comments_count": pd.Int64Dtype(),
    "comments_disabled": pd.BooleanDtype(),
    "taken_at_timestamp": pd.Int64Dtype(),
    "likes_count": pd.Int64Dtype(),
    "video_duration": pd.Float64Dtype(),
}
        
# Populate DTYPE_DICT with desired metrics for 36 reels
for i in range(1, 37):
    for metric, dtype in reel_metrics.items():
        column_name = reel_column_pattern.format(i, metric)
        DTYPE_DICT[column_name] = dtype

# Get a list of desired columns (for `read_csv()`)
columns_to_read = list(DTYPE_DICT.keys())

# Preview
# TODO: Later may copy the dict output directly into the constant module, or to make reproducible, keep the above code as is
DTYPE_DICT
# Out:
# {'user_id': Int64Dtype(),
#  'status': string[python],
#  'timestamp': Int64Dtype(),
#  'data.user_data.meta.is_private': BooleanDtype,
#  'data.user_data.meta.is_verified': BooleanDtype,
#  'data.user_data.meta.is_business_account': BooleanDtype,
#  'data.user_data.meta.is_professional_account': BooleanDtype,
#  'data.user_data.meta.has_reel': BooleanDtype,
#  'data.user_data.meta.total_posts_count': Int64Dtype(),
#  'data.user_data.meta.followers_count': Int64Dtype(),
#  'data.user_data.meta.followings_count': Int64Dtype(),
#  'data.user_data.post.1.is_video': BooleanDtype,
#  'data.user_data.post.1.video_view_count': Int64Dtype(),
#  'data.user_data.post.1.comments_count': Int64Dtype(),
#  'data.user_data.post.1.comments_disabled': BooleanDtype,
#  'data.user_data.post.1.taken_at_timestamp': Int64Dtype(),
#  'data.user_data.post.1.likes_count': Int64Dtype(),
#  'data.user_data.post.1.is_pinned': BooleanDtype,
#  'data.user_data.post.2.is_video': BooleanDtype,
#  'data.user_data.post.2.video_view_count': Int64Dtype(),
#  'data.user_data.post.2.comments_count': Int64Dtype(),
#  'data.user_data.post.2.comments_disabled': BooleanDtype,
#  'data.user_data.post.2.taken_at_timestamp': Int64Dtype(),
#  'data.user_data.post.2.likes_count': Int64Dtype(),
#  'data.user_data.post.2.is_pinned': BooleanDtype,
#  'data.user_data.post.3.is_video': BooleanDtype,
#  'data.user_data.post.3.video_view_count': Int64Dtype(),
#  'data.user_data.post.3.comments_count': Int64Dtype(),
#  'data.user_data.post.3.comments_disabled': BooleanDtype,
#  'data.user_data.post.3.taken_at_timestamp': Int64Dtype(),
#  'data.user_data.post.3.likes_count': Int64Dtype(),
#  'data.user_data.post.3.is_pinned': BooleanDtype,
#  'data.user_data.post.4.is_video': BooleanDtype,
#  'data.user_data.post.4.video_view_count': Int64Dtype(),
#  'data.user_data.post.4.comments_count': Int64Dtype(),
#  'data.user_data.post.4.comments_disabled': BooleanDtype,
#  'data.user_data.post.4.taken_at_timestamp': Int64Dtype(),
#  'data.user_data.post.4.likes_count': Int64Dtype(),
#  'data.user_data.post.4.is_pinned': BooleanDtype,
#  'data.user_data.post.5.is_video': BooleanDtype,
#  'data.user_data.post.5.video_view_count': Int64Dtype(),
#  'data.user_data.post.5.comments_count': Int64Dtype(),
#  'data.user_data.post.5.comments_disabled': BooleanDtype,
#  'data.user_data.post.5.taken_at_timestamp': Int64Dtype(),
#  'data.user_data.post.5.likes_count': Int64Dtype(),
#  'data.user_data.post.5.is_pinned': BooleanDtype,
#  'data.user_data.post.6.is_video': BooleanDtype,
#  'data.user_data.post.6.video_view_count': Int64Dtype(),
#  'data.user_data.post.6.comments_count': Int64Dtype(),
#  'data.user_data.post.6.comments_disabled': BooleanDtype,
#  'data.user_data.post.6.taken_at_timestamp': Int64Dtype(),
#  'data.user_data.post.6.likes_count': Int64Dtype(),
#  'data.user_data.post.6.is_pinned': BooleanDtype,
#  'data.user_data.post.7.is_video': BooleanDtype,
#  'data.user_data.post.7.video_view_count': Int64Dtype(),
#  'data.user_data.post.7.comments_count': Int64Dtype(),
#  'data.user_data.post.7.comments_disabled': BooleanDtype,
#  'data.user_data.post.7.taken_at_timestamp': Int64Dtype(),
#  'data.user_data.post.7.likes_count': Int64Dtype(),
#  'data.user_data.post.7.is_pinned': BooleanDtype,
#  'data.user_data.post.8.is_video': BooleanDtype,
#  'data.user_data.post.8.video_view_count': Int64Dtype(),
#  'data.user_data.post.8.comments_count': Int64Dtype(),
#  'data.user_data.post.8.comments_disabled': BooleanDtype,
#  'data.user_data.post.8.taken_at_timestamp': Int64Dtype(),
#  'data.user_data.post.8.likes_count': Int64Dtype(),
#  'data.user_data.post.8.is_pinned': BooleanDtype,
#  'data.user_data.post.9.is_video': BooleanDtype,
#  'data.user_data.post.9.video_view_count': Int64Dtype(),
#  'data.user_data.post.9.comments_count': Int64Dtype(),
#  'data.user_data.post.9.comments_disabled': BooleanDtype,
#  'data.user_data.post.9.taken_at_timestamp': Int64Dtype(),
#  'data.user_data.post.9.likes_count': Int64Dtype(),
#  'data.user_data.post.9.is_pinned': BooleanDtype,
#  'data.user_data.post.10.is_video': BooleanDtype,
#  'data.user_data.post.10.video_view_count': Int64Dtype(),
#  'data.user_data.post.10.comments_count': Int64Dtype(),
#  'data.user_data.post.10.comments_disabled': BooleanDtype,
#  'data.user_data.post.10.taken_at_timestamp': Int64Dtype(),
#  'data.user_data.post.10.likes_count': Int64Dtype(),
#  'data.user_data.post.10.is_pinned': BooleanDtype,
#  'data.user_data.post.11.is_video': BooleanDtype,
#  'data.user_data.post.11.video_view_count': Int64Dtype(),
#  'data.user_data.post.11.comments_count': Int64Dtype(),
#  'data.user_data.post.11.comments_disabled': BooleanDtype,
#  'data.user_data.post.11.taken_at_timestamp': Int64Dtype(),
#  'data.user_data.post.11.likes_count': Int64Dtype(),
#  'data.user_data.post.11.is_pinned': BooleanDtype,
#  'data.user_data.post.12.is_video': BooleanDtype,
#  'data.user_data.post.12.video_view_count': Int64Dtype(),
#  'data.user_data.post.12.comments_count': Int64Dtype(),
#  'data.user_data.post.12.comments_disabled': BooleanDtype,
#  'data.user_data.post.12.taken_at_timestamp': Int64Dtype(),
#  'data.user_data.post.12.likes_count': Int64Dtype(),
#  'data.user_data.post.12.is_pinned': BooleanDtype,
#  'data.user_data.reel.1.has_audio': BooleanDtype,
#  'data.user_data.reel.1.video_view_count': Int64Dtype(),
#  'data.user_data.reel.1.comments_count': Int64Dtype(),
#  'data.user_data.reel.1.comments_disabled': BooleanDtype,
#  'data.user_data.reel.1.taken_at_timestamp': Int64Dtype(),
#  'data.user_data.reel.1.likes_count': Int64Dtype(),
#  'data.user_data.reel.1.video_duration': Float64Dtype(),
#  'data.user_data.reel.2.has_audio': BooleanDtype,
#  'data.user_data.reel.2.video_view_count': Int64Dtype(),
#  'data.user_data.reel.2.comments_count': Int64Dtype(),
#  'data.user_data.reel.2.comments_disabled': BooleanDtype,
#  'data.user_data.reel.2.taken_at_timestamp': Int64Dtype(),
#  'data.user_data.reel.2.likes_count': Int64Dtype(),
#  'data.user_data.reel.2.video_duration': Float64Dtype(),
#  'data.user_data.reel.3.has_audio': BooleanDtype,
#  'data.user_data.reel.3.video_view_count': Int64Dtype(),
#  'data.user_data.reel.3.comments_count': Int64Dtype(),
#  'data.user_data.reel.3.comments_disabled': BooleanDtype,
#  'data.user_data.reel.3.taken_at_timestamp': Int64Dtype(),
#  'data.user_data.reel.3.likes_count': Int64Dtype(),
#  'data.user_data.reel.3.video_duration': Float64Dtype(),
#  'data.user_data.reel.4.has_audio': BooleanDtype,
#  'data.user_data.reel.4.video_view_count': Int64Dtype(),
#  'data.user_data.reel.4.comments_count': Int64Dtype(),
#  'data.user_data.reel.4.comments_disabled': BooleanDtype,
#  'data.user_data.reel.4.taken_at_timestamp': Int64Dtype(),
#  'data.user_data.reel.4.likes_count': Int64Dtype(),
#  'data.user_data.reel.4.video_duration': Float64Dtype(),
#  'data.user_data.reel.5.has_audio': BooleanDtype,
#  'data.user_data.reel.5.video_view_count': Int64Dtype(),
#  'data.user_data.reel.5.comments_count': Int64Dtype(),
#  'data.user_data.reel.5.comments_disabled': BooleanDtype,
#  'data.user_data.reel.5.taken_at_timestamp': Int64Dtype(),
#  'data.user_data.reel.5.likes_count': Int64Dtype(),
#  'data.user_data.reel.5.video_duration': Float64Dtype(),
#  'data.user_data.reel.6.has_audio': BooleanDtype,
#  'data.user_data.reel.6.video_view_count': Int64Dtype(),
#  'data.user_data.reel.6.comments_count': Int64Dtype(),
#  'data.user_data.reel.6.comments_disabled': BooleanDtype,
#  'data.user_data.reel.6.taken_at_timestamp': Int64Dtype(),
#  'data.user_data.reel.6.likes_count': Int64Dtype(),
#  'data.user_data.reel.6.video_duration': Float64Dtype(),
#  'data.user_data.reel.7.has_audio': BooleanDtype,
#  'data.user_data.reel.7.video_view_count': Int64Dtype(),
#  'data.user_data.reel.7.comments_count': Int64Dtype(),
#  'data.user_data.reel.7.comments_disabled': BooleanDtype,
#  'data.user_data.reel.7.taken_at_timestamp': Int64Dtype(),
#  'data.user_data.reel.7.likes_count': Int64Dtype(),
#  'data.user_data.reel.7.video_duration': Float64Dtype(),
#  'data.user_data.reel.8.has_audio': BooleanDtype,
#  'data.user_data.reel.8.video_view_count': Int64Dtype(),
#  'data.user_data.reel.8.comments_count': Int64Dtype(),
#  'data.user_data.reel.8.comments_disabled': BooleanDtype,
#  'data.user_data.reel.8.taken_at_timestamp': Int64Dtype(),
#  'data.user_data.reel.8.likes_count': Int64Dtype(),
#  'data.user_data.reel.8.video_duration': Float64Dtype(),
#  'data.user_data.reel.9.has_audio': BooleanDtype,
#  'data.user_data.reel.9.video_view_count': Int64Dtype(),
#  'data.user_data.reel.9.comments_count': Int64Dtype(),
#  'data.user_data.reel.9.comments_disabled': BooleanDtype,
#  'data.user_data.reel.9.taken_at_timestamp': Int64Dtype(),
#  'data.user_data.reel.9.likes_count': Int64Dtype(),
#  'data.user_data.reel.9.video_duration': Float64Dtype(),
#  'data.user_data.reel.10.has_audio': BooleanDtype,
#  'data.user_data.reel.10.video_view_count': Int64Dtype(),
#  'data.user_data.reel.10.comments_count': Int64Dtype(),
#  'data.user_data.reel.10.comments_disabled': BooleanDtype,
#  'data.user_data.reel.10.taken_at_timestamp': Int64Dtype(),
#  'data.user_data.reel.10.likes_count': Int64Dtype(),
#  'data.user_data.reel.10.video_duration': Float64Dtype(),
#  'data.user_data.reel.11.has_audio': BooleanDtype,
#  'data.user_data.reel.11.video_view_count': Int64Dtype(),
#  'data.user_data.reel.11.comments_count': Int64Dtype(),
#  'data.user_data.reel.11.comments_disabled': BooleanDtype,
#  'data.user_data.reel.11.taken_at_timestamp': Int64Dtype(),
#  'data.user_data.reel.11.likes_count': Int64Dtype(),
#  'data.user_data.reel.11.video_duration': Float64Dtype(),
#  'data.user_data.reel.12.has_audio': BooleanDtype,
#  'data.user_data.reel.12.video_view_count': Int64Dtype(),
#  'data.user_data.reel.12.comments_count': Int64Dtype(),
#  'data.user_data.reel.12.comments_disabled': BooleanDtype,
#  'data.user_data.reel.12.taken_at_timestamp': Int64Dtype(),
#  'data.user_data.reel.12.likes_count': Int64Dtype(),
#  'data.user_data.reel.12.video_duration': Float64Dtype(),
#  'data.user_data.reel.13.has_audio': BooleanDtype,
#  'data.user_data.reel.13.video_view_count': Int64Dtype(),
#  'data.user_data.reel.13.comments_count': Int64Dtype(),
#  'data.user_data.reel.13.comments_disabled': BooleanDtype,
#  'data.user_data.reel.13.taken_at_timestamp': Int64Dtype(),
#  'data.user_data.reel.13.likes_count': Int64Dtype(),
#  'data.user_data.reel.13.video_duration': Float64Dtype(),
#  'data.user_data.reel.14.has_audio': BooleanDtype,
#  'data.user_data.reel.14.video_view_count': Int64Dtype(),
#  'data.user_data.reel.14.comments_count': Int64Dtype(),
#  'data.user_data.reel.14.comments_disabled': BooleanDtype,
#  'data.user_data.reel.14.taken_at_timestamp': Int64Dtype(),
#  'data.user_data.reel.14.likes_count': Int64Dtype(),
#  'data.user_data.reel.14.video_duration': Float64Dtype(),
#  'data.user_data.reel.15.has_audio': BooleanDtype,
#  'data.user_data.reel.15.video_view_count': Int64Dtype(),
#  'data.user_data.reel.15.comments_count': Int64Dtype(),
#  'data.user_data.reel.15.comments_disabled': BooleanDtype,
#  'data.user_data.reel.15.taken_at_timestamp': Int64Dtype(),
#  'data.user_data.reel.15.likes_count': Int64Dtype(),
#  'data.user_data.reel.15.video_duration': Float64Dtype(),
#  'data.user_data.reel.16.has_audio': BooleanDtype,
#  'data.user_data.reel.16.video_view_count': Int64Dtype(),
#  'data.user_data.reel.16.comments_count': Int64Dtype(),
#  'data.user_data.reel.16.comments_disabled': BooleanDtype,
#  'data.user_data.reel.16.taken_at_timestamp': Int64Dtype(),
#  'data.user_data.reel.16.likes_count': Int64Dtype(),
#  'data.user_data.reel.16.video_duration': Float64Dtype(),
#  'data.user_data.reel.17.has_audio': BooleanDtype,
#  'data.user_data.reel.17.video_view_count': Int64Dtype(),
#  'data.user_data.reel.17.comments_count': Int64Dtype(),
#  'data.user_data.reel.17.comments_disabled': BooleanDtype,
#  'data.user_data.reel.17.taken_at_timestamp': Int64Dtype(),
#  'data.user_data.reel.17.likes_count': Int64Dtype(),
#  'data.user_data.reel.17.video_duration': Float64Dtype(),
#  'data.user_data.reel.18.has_audio': BooleanDtype,
#  'data.user_data.reel.18.video_view_count': Int64Dtype(),
#  'data.user_data.reel.18.comments_count': Int64Dtype(),
#  'data.user_data.reel.18.comments_disabled': BooleanDtype,
#  'data.user_data.reel.18.taken_at_timestamp': Int64Dtype(),
#  'data.user_data.reel.18.likes_count': Int64Dtype(),
#  'data.user_data.reel.18.video_duration': Float64Dtype(),
#  'data.user_data.reel.19.has_audio': BooleanDtype,
#  'data.user_data.reel.19.video_view_count': Int64Dtype(),
#  'data.user_data.reel.19.comments_count': Int64Dtype(),
#  'data.user_data.reel.19.comments_disabled': BooleanDtype,
#  'data.user_data.reel.19.taken_at_timestamp': Int64Dtype(),
#  'data.user_data.reel.19.likes_count': Int64Dtype(),
#  'data.user_data.reel.19.video_duration': Float64Dtype(),
#  'data.user_data.reel.20.has_audio': BooleanDtype,
#  'data.user_data.reel.20.video_view_count': Int64Dtype(),
#  'data.user_data.reel.20.comments_count': Int64Dtype(),
#  'data.user_data.reel.20.comments_disabled': BooleanDtype,
#  'data.user_data.reel.20.taken_at_timestamp': Int64Dtype(),
#  'data.user_data.reel.20.likes_count': Int64Dtype(),
#  'data.user_data.reel.20.video_duration': Float64Dtype(),
#  'data.user_data.reel.21.has_audio': BooleanDtype,
#  'data.user_data.reel.21.video_view_count': Int64Dtype(),
#  'data.user_data.reel.21.comments_count': Int64Dtype(),
#  'data.user_data.reel.21.comments_disabled': BooleanDtype,
#  'data.user_data.reel.21.taken_at_timestamp': Int64Dtype(),
#  'data.user_data.reel.21.likes_count': Int64Dtype(),
#  'data.user_data.reel.21.video_duration': Float64Dtype(),
#  'data.user_data.reel.22.has_audio': BooleanDtype,
#  'data.user_data.reel.22.video_view_count': Int64Dtype(),
#  'data.user_data.reel.22.comments_count': Int64Dtype(),
#  'data.user_data.reel.22.comments_disabled': BooleanDtype,
#  'data.user_data.reel.22.taken_at_timestamp': Int64Dtype(),
#  'data.user_data.reel.22.likes_count': Int64Dtype(),
#  'data.user_data.reel.22.video_duration': Float64Dtype(),
#  'data.user_data.reel.23.has_audio': BooleanDtype,
#  'data.user_data.reel.23.video_view_count': Int64Dtype(),
#  'data.user_data.reel.23.comments_count': Int64Dtype(),
#  'data.user_data.reel.23.comments_disabled': BooleanDtype,
#  'data.user_data.reel.23.taken_at_timestamp': Int64Dtype(),
#  'data.user_data.reel.23.likes_count': Int64Dtype(),
#  'data.user_data.reel.23.video_duration': Float64Dtype(),
#  'data.user_data.reel.24.has_audio': BooleanDtype,
#  'data.user_data.reel.24.video_view_count': Int64Dtype(),
#  'data.user_data.reel.24.comments_count': Int64Dtype(),
#  'data.user_data.reel.24.comments_disabled': BooleanDtype,
#  'data.user_data.reel.24.taken_at_timestamp': Int64Dtype(),
#  'data.user_data.reel.24.likes_count': Int64Dtype(),
#  'data.user_data.reel.24.video_duration': Float64Dtype(),
#  'data.user_data.reel.25.has_audio': BooleanDtype,
#  'data.user_data.reel.25.video_view_count': Int64Dtype(),
#  'data.user_data.reel.25.comments_count': Int64Dtype(),
#  'data.user_data.reel.25.comments_disabled': BooleanDtype,
#  'data.user_data.reel.25.taken_at_timestamp': Int64Dtype(),
#  'data.user_data.reel.25.likes_count': Int64Dtype(),
#  'data.user_data.reel.25.video_duration': Float64Dtype(),
#  'data.user_data.reel.26.has_audio': BooleanDtype,
#  'data.user_data.reel.26.video_view_count': Int64Dtype(),
#  'data.user_data.reel.26.comments_count': Int64Dtype(),
#  'data.user_data.reel.26.comments_disabled': BooleanDtype,
#  'data.user_data.reel.26.taken_at_timestamp': Int64Dtype(),
#  'data.user_data.reel.26.likes_count': Int64Dtype(),
#  'data.user_data.reel.26.video_duration': Float64Dtype(),
#  'data.user_data.reel.27.has_audio': BooleanDtype,
#  'data.user_data.reel.27.video_view_count': Int64Dtype(),
#  'data.user_data.reel.27.comments_count': Int64Dtype(),
#  'data.user_data.reel.27.comments_disabled': BooleanDtype,
#  'data.user_data.reel.27.taken_at_timestamp': Int64Dtype(),
#  'data.user_data.reel.27.likes_count': Int64Dtype(),
#  'data.user_data.reel.27.video_duration': Float64Dtype(),
#  'data.user_data.reel.28.has_audio': BooleanDtype,
#  'data.user_data.reel.28.video_view_count': Int64Dtype(),
#  'data.user_data.reel.28.comments_count': Int64Dtype(),
#  'data.user_data.reel.28.comments_disabled': BooleanDtype,
#  'data.user_data.reel.28.taken_at_timestamp': Int64Dtype(),
#  'data.user_data.reel.28.likes_count': Int64Dtype(),
#  'data.user_data.reel.28.video_duration': Float64Dtype(),
#  'data.user_data.reel.29.has_audio': BooleanDtype,
#  'data.user_data.reel.29.video_view_count': Int64Dtype(),
#  'data.user_data.reel.29.comments_count': Int64Dtype(),
#  'data.user_data.reel.29.comments_disabled': BooleanDtype,
#  'data.user_data.reel.29.taken_at_timestamp': Int64Dtype(),
#  'data.user_data.reel.29.likes_count': Int64Dtype(),
#  'data.user_data.reel.29.video_duration': Float64Dtype(),
#  'data.user_data.reel.30.has_audio': BooleanDtype,
#  'data.user_data.reel.30.video_view_count': Int64Dtype(),
#  'data.user_data.reel.30.comments_count': Int64Dtype(),
#  'data.user_data.reel.30.comments_disabled': BooleanDtype,
#  'data.user_data.reel.30.taken_at_timestamp': Int64Dtype(),
#  'data.user_data.reel.30.likes_count': Int64Dtype(),
#  'data.user_data.reel.30.video_duration': Float64Dtype(),
#  'data.user_data.reel.31.has_audio': BooleanDtype,
#  'data.user_data.reel.31.video_view_count': Int64Dtype(),
#  'data.user_data.reel.31.comments_count': Int64Dtype(),
#  'data.user_data.reel.31.comments_disabled': BooleanDtype,
#  'data.user_data.reel.31.taken_at_timestamp': Int64Dtype(),
#  'data.user_data.reel.31.likes_count': Int64Dtype(),
#  'data.user_data.reel.31.video_duration': Float64Dtype(),
#  'data.user_data.reel.32.has_audio': BooleanDtype,
#  'data.user_data.reel.32.video_view_count': Int64Dtype(),
#  'data.user_data.reel.32.comments_count': Int64Dtype(),
#  'data.user_data.reel.32.comments_disabled': BooleanDtype,
#  'data.user_data.reel.32.taken_at_timestamp': Int64Dtype(),
#  'data.user_data.reel.32.likes_count': Int64Dtype(),
#  'data.user_data.reel.32.video_duration': Float64Dtype(),
#  'data.user_data.reel.33.has_audio': BooleanDtype,
#  'data.user_data.reel.33.video_view_count': Int64Dtype(),
#  'data.user_data.reel.33.comments_count': Int64Dtype(),
#  'data.user_data.reel.33.comments_disabled': BooleanDtype,
#  'data.user_data.reel.33.taken_at_timestamp': Int64Dtype(),
#  'data.user_data.reel.33.likes_count': Int64Dtype(),
#  'data.user_data.reel.33.video_duration': Float64Dtype(),
#  'data.user_data.reel.34.has_audio': BooleanDtype,
#  'data.user_data.reel.34.video_view_count': Int64Dtype(),
#  'data.user_data.reel.34.comments_count': Int64Dtype(),
#  'data.user_data.reel.34.comments_disabled': BooleanDtype,
#  'data.user_data.reel.34.taken_at_timestamp': Int64Dtype(),
#  'data.user_data.reel.34.likes_count': Int64Dtype(),
#  'data.user_data.reel.34.video_duration': Float64Dtype(),
#  'data.user_data.reel.35.has_audio': BooleanDtype,
#  'data.user_data.reel.35.video_view_count': Int64Dtype(),
#  'data.user_data.reel.35.comments_count': Int64Dtype(),
#  'data.user_data.reel.35.comments_disabled': BooleanDtype,
#  'data.user_data.reel.35.taken_at_timestamp': Int64Dtype(),
#  'data.user_data.reel.35.likes_count': Int64Dtype(),
#  'data.user_data.reel.35.video_duration': Float64Dtype(),
#  'data.user_data.reel.36.has_audio': BooleanDtype,
#  'data.user_data.reel.36.video_view_count': Int64Dtype(),
#  'data.user_data.reel.36.comments_count': Int64Dtype(),
#  'data.user_data.reel.36.comments_disabled': BooleanDtype,
#  'data.user_data.reel.36.taken_at_timestamp': Int64Dtype(),
#  'data.user_data.reel.36.likes_count': Int64Dtype(),
#  'data.user_data.reel.36.video_duration': Float64Dtype()}

# %% [markdown]
# ### Read and check

# %%
# Read the data
df = pd.read_csv(
    '.././data/input/instagram.csv',
    encoding='utf-8',
    index_col=False,
    usecols=columns_to_read,
    dtype=DTYPE_DICT,
)

# Get infos
print(df.info())

# Check types
print(df.dtypes)

# Check all cols for the first 10 rows
with pd.option_context('display.max_columns', None):
    print(df.head(n=10))

# One strange value found during playaround
# This timestamp was as scientific notation in the raw csv, decide what to do about it later
# df[df["user_id"] == 1098748]["data.user_data.reel.13.taken_at_timestamp"].values
# Out:
# <IntegerArray>
# [1719000000]
# Length: 1, dtype: Int64

# %% [markdown]
# ### Optional: Creating a subset for faster manipulations

# %%
# Initialize an empty DataFrame to collect the first 100 rows
subset_df = df.head(100)

# Save the subset if needed
subset_df.to_csv('.././data/input/instagram_subset.csv', index=False)
